# %%
ROOT_DIR = ""

# %%
import os
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch

# Use the model
results = model.train(data=os.path.join(ROOT_DIR, "config.yaml"), epochs=100, fliplr=0.0)  # train the model
# Out:
# New https://pypi.org/project/ultralytics/8.1.18 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.17 🚀 Python-3.12.1 torch-2.2.0+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 16061MiB)
# ...
